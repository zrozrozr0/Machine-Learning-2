# %% [markdown]
# # Practice 1
# ## Regular expressions
# ### Silva Paredes Kaeri 7CM3
# #### Natural Language Processing

# %%
import re
from collections import Counter
from reportlab.lib.pagesizes import letter
from reportlab.platypus import SimpleDocTemplate, Table, TableStyle
# Out:
# Failed to start the Kernel 'Python 3.11.5'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. spawn UNKNOWN

# %%
with open('tweets.txt', 'r', encoding='utf-8') as archivo:
    tweets = archivo.read()

# Se definen los patrones de expresiones regulares
patron_hashtags = r'#\w+'
patron_usuarios = r'@\w+'
patron_tiempo = r'\b(?:\d{1,2}(?::\d{2})?[apmAPM]{2}|(?:[0-1]?[0-9]|2[0-3]):[0-5][0-9])\b'
patron_emoticonos = r'[:;][)(DdPpOo3/\\]|<3|¯\\_\(ツ\)_/¯'
patron_emojis_unicode = r'[\U0001f600-\U0001f6ff]+'
# Se encuentran coincidencias
hashtags = re.findall(patron_hashtags, tweets)
usuarios = re.findall(patron_usuarios, tweets)
coincidencias_tiempo = re.findall(patron_tiempo, tweets)
emoticonos = re.findall(patron_emoticonos, tweets)
emojis_unicode = re.findall(patron_emojis_unicode, tweets)
# Se implementa Counter para contar la frecuencia de cada tipo de cadena
n_hashtags = Counter(hashtags)
n_usuarios = Counter(usuarios)
n_tiempo = Counter(coincidencias_tiempo)
n_emoticonos = Counter(emoticonos)
n_emojis_unicode = Counter(emojis_unicode)


top10_hashtags = n_hashtags.most_common(10)
top10_usuarios = n_usuarios.most_common(10)
top10_tiempo = n_tiempo.most_common(10)
top10_emoticonos = n_emoticonos.most_common(10)
top10_emojis_unicode = n_emojis_unicode.most_common(10)


data = [("Elemento (Hashtags)", "Frecuencia de elemento ", "Top 10 elemento"),
        *[("Hashtags", freq, hashtag) for hashtag, freq in top10_hashtags],
        ("Elemento (Usuarios)", "Frecuencia de elemento", "Top 10 elemento"),
        *[("Usuarios", freq, usuario) for usuario, freq in top10_usuarios], 
        ("Elemento (Tiempo)", "Frecuencia de elemento", "Top 10 elemento"),
        *[("Tiempo", freq, tiempo) for tiempo, freq in top10_tiempo],
        ("Elemento (Emoticonos en ASCII)", "Frecuencia de Elemento", "Top 10 elemento"),
        *[("Emoticonos en ASCII", freq, emoticono) for emoticono, freq in top10_emoticonos],
        ("Elemento (Emoji Unicode)", "Frecuencia de Elemento", "Top 10 elemento"),
        *[("Emoji Unicode", freq, emojis_unicode) for emojis_unicode, freq in top10_emojis_unicode]
       ]

print(tabulate(data, headers=["Elemento", "Frecuencia", "Top 10"], tablefmt="grid"))
# Out:
# +--------------------------------+------------------------+-----------------+
# | Elemento                       | Frecuencia             | Top 10          |
# +================================+========================+=================+
# | Elemento (Hashtags)            | Frecuencia de elemento | Top 10 elemento |
# +--------------------------------+------------------------+-----------------+
# | Hashtags                       | 37                     | #ironía         |
# +--------------------------------+------------------------+-----------------+
# | Hashtags                       | 19                     | #Ironía         |
# +--------------------------------+------------------------+-----------------+
# | Hashtags                       | 17                     | #miedo          |
# +--------------------------------+------------------------+-----------------+
# | Hashtags                       | 17                     | #sarcasmo       |
# +--------------------------------+------------------------+-----------------+
# | Hashtags                       | 15                     | #KCAMexico      |
# +--------------------------------+------------------------+-----------------+
# | Hashtags                       | 13                     | #Rayito         |
# +--------------------------------+------------------------+-----------------+
# | Hashtags                       | 12                     | #triste         |
# +--------------------------------+------------------------+-----------------+
# | Hashtags                       | 11                     | #ironia         |
# +--------------------------------+------------------------+-----------------+
# | Hashtags                       | 10                     | #Feliz          |
# +--------------------------------+------------------------+-----------------+
# | Hashtags                       | 10                     | #Sarcasmo       |
# +--------------------------------+------------------------+-----------------+
# | Elemento (Usuarios)            | Frecuencia de elemento | Top 10 elemento |
# +--------------------------------+------------------------+-----------------+
# | Usuarios                       | 17                     | @DebRyanShow    |
# +--------------------------------+------------------------+-----------------+
# | Usuarios                       | 7                      | @mariobautista_ |
# +--------------------------------+------------------------+-----------------+
# | Usuarios                       | 6                      | @BrunoMars      |
# +--------------------------------+------------------------+-----------------+
# | Usuarios                       | 5                      | @DalasReview    |
# +--------------------------------+------------------------+-----------------+
# | Usuarios                       | 5                      | @Camila_Cabello |
# +--------------------------------+------------------------+-----------------+
# | Usuarios                       | 4                      | @s              |
# +--------------------------------+------------------------+-----------------+
# | Usuarios                       | 4                      | @D99Radio       |
# +--------------------------------+------------------------+-----------------+
# | Usuarios                       | 4                      | @enjambremx     |
# +--------------------------------+------------------------+-----------------+
# | Usuarios                       | 4                      | @clubleonfc     |
# +--------------------------------+------------------------+-----------------+
# | Usuarios                       | 4                      | @BTS_twt        |
# +--------------------------------+------------------------+-----------------+
# | Elemento (Tiempo)              | Frecuencia de elemento | Top 10 elemento |
# +--------------------------------+------------------------+-----------------+
# | Tiempo                         | 2                      | 1:21            |
# +--------------------------------+------------------------+-----------------+
# | Tiempo                         | 2                      | 8:30            |
# +--------------------------------+------------------------+-----------------+
# | Tiempo                         | 2                      | 23:04           |
# +--------------------------------+------------------------+-----------------+
# | Tiempo                         | 2                      | 12:00           |
# +--------------------------------+------------------------+-----------------+
# | Tiempo                         | 2                      | 1am             |
# +--------------------------------+------------------------+-----------------+
# | Tiempo                         | 1                      | 10:19           |
# +--------------------------------+------------------------+-----------------+
# | Tiempo                         | 1                      | 6:00            |
# +--------------------------------+------------------------+-----------------+
# | Tiempo                         | 1                      | 6:30am          |
# +--------------------------------+------------------------+-----------------+
# | Tiempo                         | 1                      | 6:59            |
# +--------------------------------+------------------------+-----------------+
# | Tiempo                         | 1                      | 3:20            |
# +--------------------------------+------------------------+-----------------+
# | Elemento (Emoticonos en ASCII) | Frecuencia de Elemento | Top 10 elemento |
# +--------------------------------+------------------------+-----------------+
# | Emoticonos en ASCII            | 27                     | :(              |
# +--------------------------------+------------------------+-----------------+
# | Emoticonos en ASCII            | 11                     | :3              |
# +--------------------------------+------------------------+-----------------+
# | Emoticonos en ASCII            | 5                      | :)              |
# +--------------------------------+------------------------+-----------------+
# | Emoticonos en ASCII            | 5                      | :/              |
# +--------------------------------+------------------------+-----------------+
# | Emoticonos en ASCII            | 4                      | <3              |
# +--------------------------------+------------------------+-----------------+
# | Emoticonos en ASCII            | 3                      | ;)              |
# +--------------------------------+------------------------+-----------------+
# | Emoticonos en ASCII            | 2                      | :D              |
# +--------------------------------+------------------------+-----------------+
# | Emoticonos en ASCII            | 1                      | :p              |
# +--------------------------------+------------------------+-----------------+
# | Emoticonos en ASCII            | 1                      | ¯\_(ツ)_/¯      |
# +--------------------------------+------------------------+-----------------+
# | Emoticonos en ASCII            | 1                      | :o              |
# +--------------------------------+------------------------+-----------------+
# | Elemento (Emoji Unicode)       | Frecuencia de Elemento | Top 10 elemento |
# +--------------------------------+------------------------+-----------------+
# | Emoji Unicode                  | 58                     | 😂              |
# +--------------------------------+------------------------+-----------------+
# | Emoji Unicode                  | 40                     | 😭              |
# +--------------------------------+------------------------+-----------------+
# | Emoji Unicode                  | 36                     | 😢              |
# +--------------------------------+------------------------+-----------------+
# | Emoji Unicode                  | 35                     | 😊              |
# +--------------------------------+------------------------+-----------------+
# | Emoji Unicode                  | 34                     | 😅              |
# +--------------------------------+------------------------+-----------------+
# | Emoji Unicode                  | 24                     | 😥              |
# +--------------------------------+------------------------+-----------------+
# | Emoji Unicode                  | 22                     | 😍              |
# +--------------------------------+------------------------+-----------------+
# | Emoji Unicode                  | 22                     | 🙁              |
# +--------------------------------+------------------------+-----------------+
# | Emoji Unicode                  | 19                     | 😟              |
# +--------------------------------+------------------------+-----------------+
# | Emoji Unicode                  | 17                     | 😂😂            |
# +--------------------------------+------------------------+-----------------+

# %%
#En esta seccion del codigo automatizamos la tabla para pasarla directamente a pdf

output_file = "Tabla_Datos_Tweets.pdf"


doc = SimpleDocTemplate(output_file, pagesize=letter)


table = Table(data)


style = TableStyle([('BACKGROUND', (0, 0), (-1, 0), (0.8, 0.8, 0.8)),
                    ('ALIGN', (0, 0), (-1, -1), 'CENTER'),
                    ('FONTNAME', (0, 0), (-1, 0), 'Helvetica-Bold'),
                    ('BOTTOMPADDING', (0, 0), (-1, 0), 12),
                    ('BACKGROUND', (0, 1), (-1, -1), (0.9, 0.9, 0.9)),
                    ('GRID', (0, 0), (-1, -1), 1, (0, 0, 0)),
                    ('ALIGN', (1, 1), (-1, -1), 'RIGHT'),
                    ('FONTNAME', (0, 1), (-1, -1), 'Helvetica'),
                    ('BOTTOMPADDING', (0, 1), (-1, -1), 6),
                    ('BACKGROUND', (0, 1), (-1, 1), (0.7, 0.7, 0.7)),
                    ])


table.setStyle(style)


content = [table]
doc.build(content)

print(f"El archivo PDF '{output_file}' ha sido creado con éxito.")
# Out:
# El archivo PDF 'Tabla_Datos_Tweets.pdf' ha sido creado con éxito.
